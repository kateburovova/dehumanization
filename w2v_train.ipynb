# %%
import gensim
import pandas as pd
import ast
import pandas as pd
import numpy as np

# %%
# df_lemmas = pd.read_csv('/Users/katerynaburovova/PycharmProjects/dehumanization/data/all_lemmas.csv', index_col = [0])

# %% [markdown]
# ## Training on the whole dataset

# %%
# %%time

df_lemmas = pd.read_csv('/Users/katerynaburovova/PycharmProjects/dehumanization/data/all_lemmas.csv', index_col = [0])

df_lemmas['message_lemmas_list'] = df_lemmas['message_lemmas_list'].apply(ast.literal_eval)

# %%
documents = df_lemmas['message_lemmas_list'].to_list()

# %%
# %%time
model = gensim.models.Word2Vec (documents, vector_size=150, window=10, min_count=2, workers=10)
model.train(documents,total_examples=len(documents),epochs=10)

# %%
model.save('/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec_correct.model')

# %%
# %%time
model = gensim.models.Word2Vec (documents, vector_size=300, window=10, min_count=2, workers=10)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# CPU times: user 4h 51min 33s, sys: 28min 31s, total: 5h 20min 5s
# Wall time: 2h 12min 57s
# (3319614815, 3940965080)

# %%
model.save('/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec_correct_300.model')

# %%
# model_ = gensim.models.Word2Vec.load('/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec.model')

# %%
w1 = "россиянин"
model.wv.most_similar(positive=w1, topn=30)
# Out:
# [('гражданин', 0.6260555982589722),
#  ('иностранец', 0.6161984801292419),
#  ('респондент', 0.5866599082946777),
#  ('согражданин', 0.5792011022567749),
#  ('москвич', 0.5500414967536926),
#  ('турист', 0.5197361707687378),
#  ('украинец', 0.5189060568809509),
#  ('человек', 0.5046504139900208),
#  ('британец', 0.4958539605140686),
#  ('казахстанец', 0.49145030975341797),
#  ('американец', 0.48877468705177307),
#  ('соотечественник', 0.47792723774909973),
#  ('петербуржец', 0.4773894250392914),
#  ('мигрант', 0.4758749008178711),
#  ('европеец', 0.4724271893501282),
#  ('белорус', 0.4628015458583832),
#  ('население', 0.4620310366153717),
#  ('житель', 0.4598851501941681),
#  ('россиянка', 0.4535672664642334),
#  ('пользователь', 0.4482652246952057),
#  ('опросить', 0.44760861992836),
#  ('путешественник', 0.44352179765701294),
#  ('россия', 0.431467741727829),
#  ('крымчанин', 0.42702823877334595),
#  ('афганец', 0.42592233419418335),
#  ('горожанин', 0.42527905106544495),
#  ('русских', 0.4248400628566742),
#  ('беженец', 0.4248102903366089),
#  ('клиент', 0.42013561725616455),
#  ('гастарбайтер', 0.4185965359210968)]

# %%
# # from gensim.models import Word2Vec
# #
#
# # model_path = '/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec.model'
# # model = Word2Vec.load(model_path)
#
# vocabulary = list(model.wv.index_to_key)
#
# print(vocabulary)

# %% [markdown]
# ## Averaging the morphological forms

# %% [markdown]
# Here I find all the morphological forms of the most popular labels. I additionaly find the misspelled versions (excluding those that are in fact real different words).

# %%
from gensim.models import Word2Vec
model_path = '/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec_correct.model'
model = Word2Vec.load(model_path)

# %%
w1 = 'хохлушка'
model.wv.most_similar(positive=w1, topn=30)
# Out:
# [('нацистка', 0.6061878800392151),
#  ('шалава', 0.6014500260353088),
#  ('шмара', 0.5997158288955688),
#  ('бабища', 0.5862389802932739),
#  ('бандеровка', 0.580834150314331),
#  ('мерзавка', 0.5768174529075623),
#  ('дамочка', 0.5684010982513428),
#  ('украинка', 0.5600405335426331),
#  ('дивчина', 0.5577738285064697),
#  ('карлица', 0.5557477474212646),
#  ('бабёнка', 0.5546216368675232),
#  ('девка', 0.5523253679275513),
#  ('хабалка', 0.5515905618667603),
#  ('деваха', 0.5451499223709106),
#  ('стерва', 0.5445281863212585),
#  ('одесситка', 0.5409867167472839),
#  ('алкоголичка', 0.5364329814910889),
#  ('жинка', 0.5354903340339661),
#  ('свинособака', 0.5255479216575623),
#  ('пропагандистка', 0.525350034236908),
#  ('ципсота', 0.5225162506103516),
#  ('свинособак', 0.5224473476409912),
#  ('шлюха', 0.5222390294075012),
#  ('танька', 0.5213223099708557),
#  ('парубок', 0.5197714567184448),
#  ('юлька', 0.5162315368652344),
#  ('истеричка', 0.5158720016479492),
#  ('полуграмотная', 0.5151511430740356),
#  ('еврейка', 0.5148496031761169),
#  ('хлопец', 0.5145063400268555)]

# %%
popular_label_list = ['укр',
                      'украинец',
                      'украинка',
                      'хохол',
                      'хохлушка',
                      'укроп',
                      'Украина',
                      'украинский',
                      'украинская',
                      'украинское',
                      'хохлятский',
                      'хохлятская',
                      'хохлятское',
                      'укропский', #укровский сюди ж піде в рамках місспеллінга
                      'укропская',
                      'укропское']

# %%
import pymorphy2

def get_word_forms(word):
    morph = pymorphy2.MorphAnalyzer()
    parsed_word = morph.parse(word)
    forms = set()
    for parse_result in parsed_word:
        for form in parse_result.lexeme:
            forms.add(form.word)
    return forms

# %%
all_forms_dict = {}
for word in popular_label_list:
    all_forms_dict[word]=get_word_forms(word)

# %%
all_forms_dict
# Out:
# {'укр': {'укр'},
#  'украинец': {'украинец',
#   'украинца',
#   'украинцам',
#   'украинцами',
#   'украинцах',
#   'украинце',
#   'украинцев',
#   'украинцем',
#   'украинцу',
#   'украинцы'},
#  'украинка': {'украинка',
#   'украинкам',
#   'украинками',
#   'украинках',
#   'украинке',
#   'украинки',
#   'украинкой',
#   'украинкою',
#   'украинку',
#   'украинок'},
#  'хохол': {'хохла',
#   'хохлам',
#   'хохлами',
#   'хохлах',
#   'хохле',
#   'хохлов',
#   'хохлом',
#   'хохлу',
#   'хохлы',
#   'хохол'},
#  'хохлушка': {'хохлушек',
#   'хохлушка',
#   'хохлушкам',
#   'хохлушками',
#   'хохлушках',
#   'хохлушке',
#   'хохлушки',
#   'хохлушкой',
#   'хохлушкою',
#   'хохлушку'},
#  'укроп': {'укроп',
#   'укропа',
#   'укропам',
#   'укропами',
#   'укропах',
#   'укропе',
#   'укропов',
#   'укропом',
#   'укропу',
#   'укропы'},
#  'Украина': {'украина',
#   'украине',
#   'украиной',
#   'украиною',
#   'украину',
#   'украины'},
#  'украинский': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'украинская': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'украинское': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'хохлятский': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'хохлятская': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'хохлятское': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'укропский': {'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'},
#  'укропская': {'укропскае',
#   'укропскаем',
#   'укропскай',
#   'укропскаю',
#   'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'},
#  'укропское': {'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'}}

# %%
target_word = "хохлушка"
max_distance = 1

# misspelled_versions = find_misspelled_words(model, target_word, max_distance)

# %%
vocabulary = list(model.wv.index_to_key)

# %%
len(vocabulary)
# Out:
# 879663

# %%
def is_misspelled(word):
    morph = pymorphy2.MorphAnalyzer()
    parsed_word = morph.parse(word)
    for parse_result in parsed_word:
        if parse_result.tag.POS is not None:
            return False
    return True

# %%
word_to_check = "хxол"
is_word_misspelled = is_misspelled(word_to_check)
if is_word_misspelled:
    print(f"The word '{word_to_check}' is a misspelling.")
else:
    print(f"The word '{word_to_check}' is a real word.")
# Out:
# The word 'хxол' is a real word.

# %% [markdown]
# Neither pyspellchecker nor pymorphy2 is able to reliably tell the difference between the real and misspelled word (the example is above), so we'll look trough the possible misspellings (Levenstein distance 1 for every inflected form) and relying on our Russian language knowledge select the misspelled versions. Those will be considered for inclusion in the general list of morphological forms.

# %%
import Levenshtein

def find_misspelled_words(model, target_word, max_distance):
    misspelled_words = []
    for word in model.wv.key_to_index:
        if abs(len(word) - len(target_word)) <= max_distance:
            distance = Levenshtein.distance(target_word, word)
            if distance <= max_distance:
                misspelled_words.append(word)

    return misspelled_words

# %%
target_word = "хохлушка"
max_distance = 1

misspelled_versions = find_misspelled_words(model, target_word, max_distance)
misspelled_versions
# Out:
# ['хохлушка', 'хохлуша', 'хохлушкам']

# %%
# We're creating the list with all the valid inflections to check misspelling against to

all_inflection_list = [all_forms_dict[word] for word in popular_label_list]
all_inflection_list = [item for d in all_inflection_list for item in d]

# %%
misspellings_dict = {}
for word in all_forms_dict:
    inflected_word_list = list(all_forms_dict[word])
    all_misspellings_for_word = []
    for word_form in inflected_word_list:
        misspellings = find_misspelled_words(model, word_form, max_distance)
        misspellings = [misspelled_form for misspelled_form in misspellings if misspelled_form not in all_inflection_list]
        all_misspellings_for_word.append(misspellings)
    all_misspellings_for_word = [item for sublist in all_misspellings_for_word for item in sublist]

    misspellings_dict[word]=all_misspellings_for_word

# %%
misspellings_to_remove = {'укр': ['ук', 'скр', 'укры', 'нкр', 'окр', 'кр', 'пкр', 'ур', 'акр', 'укор', 'мкр', 'уур', 'унр', 'укро','угр','укс','укрф', 'уяр','укра','дкр','фкр','ркр','вкр','уку','укв','упр','уки','цкр','укре','зкр','гкр','укз','уор','ука','утр','ткр','укн','уктр','укб','убр','укх','увр','гукр','урр','умр','икр','уэр','удр','укт', 'укп','укм','уко','укнр','ушр','укрл','укрп','екр','ухр','бкр','шкр','уир','укрв'],
                          'украинец': ['украинск', 'украинам','украинру'],

                          'украинка': ['украинах', 'украинких', 'украинкая', 'украинск', 'украинои','украинкую', 'укранкою','украинкую', 'украинру', 'украински', 'украини', 'украинои', 'украиныи', 'украинких', 'украинкие', 'украинуи', 'украиской', 'украиныой', 'украиснкой', 'украинуой','украинуой', 'украинске', 'украинкие','украинам', 'украинкая','украинкая','украинска', 'украинеа','украинами'],

                          'хохол': ['хохот','хохо','хорол','бохол','хохон','хохламы','хохмам','хозлам','хохму','хохма','хотла','хоха','сохла', 'хойла','хола','холла','хоула','хохловя','хохлову','рохлов','хихлов','хозлов','хохлотв','дхохлов','хохлово','хохлому','хохлома','хохломы','хохло','хойлом','хохломе','хохмы','холлы','хозлы','хорлы', 'хохлыс','холы','холе','холле','хохуле','хохе','хохе'],

                          'хохлушка': [],

                          'укроп':['укрепов','укропол','укропоп','укроптв','укреп','укрой','кроп','укропв','укрокп','укрою','укрп','укрепам','укроспам','укрепом','укропол','укропоп','укрепе','укропв','укрепа','укропв','укрепы','укрепами','укрепах','укрепу'],

                          'Украина':['украиныс','украинц','украинв','украицы','окраины','уокраины','окраиной','краиной','украну','краину','украинц','украинру','украинуи','украиру','украинут','окраина','краина','украинц','укрвина','укранна','укрпина','краине','украинев','украинц','окраине', 'украинес'],

                          'украинский':[],

                          'украинская': [],

                          'украинское': [],

                          'хохлятский': [],

                          'хохлятская': [],

                          'хохлятское': [],

                          'укропский': [],

                          'укропская': [],

                          'укропское': []
                          }

# %% [markdown]
# The unfortunate downside is that for some words misspellings look more like just the other word, so validity of the choice to remove is decided on the level of the word, not the general list.
#
# It could be beneficial to include also украино, хохло, укро.

# %%
clean_misspellings_dict = {}
for word in popular_label_list:
    misspells = [word_ for word_ in misspellings_dict[word] if word_ not in misspellings_to_remove[word]]
    clean_misspellings_dict[word] = misspells

# %%
clean_misspellings_dict
# Out:
# {'укр': ['укру', 'укри'],
#  'украинец': ['украинци',
#   'украинц',
#   'украинеа',
#   'яукраинца',
#   'украинци',
#   'украинц',
#   'кукраинцам',
#   'усраинцам',
#   'украинцям',
#   'укранцем',
#   'украинцям',
#   'украинах',
#   'украинци',
#   'окраинцы',
#   'яукраинцы',
#   'украинц',
#   'украдинцы',
#   'украицы',
#   'усраинцы',
#   'укроинцы',
#   'украйнцы',
#   'краинцы',
#   'окраинцами',
#   'сукраинцами',
#   'украинами',
#   'оукраинцами',
#   'украинцева',
#   'иукраинцев',
#   'украинцеву',
#   'украинев',
#   'уукраинцев',
#   'укранцев',
#   'украинцевъ',
#   'украицев',
#   'усраинцев',
#   'окраинцев',
#   'украиснцев',
#   'уараинцев',
#   'украинцевс',
#   'украиньцев',
#   'украинци',
#   'украинц',
#   'украинеи',
#   'украинев',
#   'украинець',
#   'украинц',
#   'вукраинец',
#   'укранец',
#   'окраинец',
#   'украинес',
#   'иукраинец',
#   'украинеа',
#   'украиниц'],
#  'украинка': ['укранка',
#   'краинка',
#   'украинци',
#   'украинеи',
#   'укранки',
#   'укринки',
#   'украино',
#   'укранок'],
#  'хохол': ['хохл',
#   'хохли',
#   'хохлв',
#   'хохола',
#   'ххла',
#   'хохл',
#   'хохли',
#   'хохлух',
#   'хохлв',
#   'хихлам',
#   'лохлам',
#   'хохолам',
#   'хахлам',
#   'хихлами',
#   'хохлми',
#   'хохл',
#   'хохли',
#   'хохлв',
#   'хохлух',
#   'хихлах',
#   'холов',
#   'хохолов',
#   'ххлов',
#   'хахлов',
#   'лохлов',
#   'хохлв',
#   'хохолы',
#   'хохоль',
#   'хохл',
#   'ххол',
#   'хохола',
#   'хахол',
#   'хохоля',
#   'яхохол',
#   'хохолы',
#   'хихлы',
#   'ххлы',
#   'хохл',
#   'хахлы',
#   'хохли',
#   'лохлы',
#   'хохлв'],
#  'хохлушка': ['хохлуша'],
#  'укроп': ['укров', 'укро', 'укром', 'укропка'],
#  'Украина': ['сукраиной',
#   'иукраиной',
#   'украинои',
#   'украино',
#   'букраиной',
#   'украной',
#   'укаиной',
#   'украиныой',
#   'оукраиной',
#   'украинуой',
#   'ураиной',
#   'усраиной',
#   'вукраину',
#   'украин',
#   'украини',
#   'украйну',
#   'иукраину',
#   'украинув',
#   'украино',
#   'укруину',
#   'укроину',
#   'усраину',
#   'укрину',
#   'украйину',
#   'ураину',
#   'букраину',
#   'украною',
#   'украинои',
#   'украино',
#   'украин',
#   'краины',
#   'иукраины',
#   'украны',
#   'украйны',
#   'украини',
#   'укрины',
#   'сукраины',
#   'ураины',
#   'букраины',
#   'уукраины',
#   'украиным',
#   'усраины',
#   'аукраины',
#   'украиныв',
#   'укруины',
#   'вукраины',
#   'украино',
#   'украиныи',
#   'укранины',
#   'укараины',
#   'вкраины',
#   'украиныр',
#   'кукраины',
#   'украиеы',
#   'укроины',
#   'укаины',
#   'вукраине',
#   'украин',
#   'украйне',
#   'украини',
#   'украинеи',
#   'ураине',
#   'укране',
#   'иукраине',
#   'укруине',
#   'кукраине',
#   'букраине',
#   'украино',
#   'укаине',
#   'усраине',
#   'укранине',
#   'укрине',
#   'украинеа',
#   'уукраине',
#   'укараине',
#   'украна',
#   'украин',
#   'украйна',
#   'иукраина',
#   'украини',
#   'аукраина',
#   'рукраина',
#   'укруина',
#   'украйина',
#   'украинах',
#   'украино',
#   'украинам',
#   'букраина',
#   'усраина',
#   'укрина',
#   'ураина',
#   'украинеа',
#   'тукраина',
#   'укараина',
#   'укранина',
#   'укаина'],
#  'украинский': ['украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'украинская': ['украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'украинское': ['украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'хохлятский': ['хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'хохлятская': ['хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'хохлятское': ['хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'укропский': ['укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровское',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровских',
#   'укропскии',
#   'укровская',
#   'укровскую'],
#  'укропская': ['укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровское',
#   'укровская',
#   'укровских',
#   'укропскии',
#   'укровскую'],
#  'укропское': ['укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровское',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровских',
#   'укропскии',
#   'укровская',
#   'укровскую']}

# %%
all_forms_dict
# Out:
# {'укр': {'укр'},
#  'украинец': {'украинец',
#   'украинца',
#   'украинцам',
#   'украинцами',
#   'украинцах',
#   'украинце',
#   'украинцев',
#   'украинцем',
#   'украинцу',
#   'украинцы'},
#  'украинка': {'украинка',
#   'украинкам',
#   'украинками',
#   'украинках',
#   'украинке',
#   'украинки',
#   'украинкой',
#   'украинкою',
#   'украинку',
#   'украинок'},
#  'хохол': {'хохла',
#   'хохлам',
#   'хохлами',
#   'хохлах',
#   'хохле',
#   'хохлов',
#   'хохлом',
#   'хохлу',
#   'хохлы',
#   'хохол'},
#  'хохлушка': {'хохлушек',
#   'хохлушка',
#   'хохлушкам',
#   'хохлушками',
#   'хохлушках',
#   'хохлушке',
#   'хохлушки',
#   'хохлушкой',
#   'хохлушкою',
#   'хохлушку'},
#  'укроп': {'укроп',
#   'укропа',
#   'укропам',
#   'укропами',
#   'укропах',
#   'укропе',
#   'укропов',
#   'укропом',
#   'укропу',
#   'укропы'},
#  'Украина': {'украина',
#   'украине',
#   'украиной',
#   'украиною',
#   'украину',
#   'украины'},
#  'украинский': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'украинская': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'украинское': {'украинская',
#   'украинские',
#   'украинский',
#   'украинским',
#   'украинскими',
#   'украинских',
#   'украинского',
#   'украинское',
#   'украинской',
#   'украинском',
#   'украинскому',
#   'украинскою',
#   'украинскую'},
#  'хохлятский': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'хохлятская': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'хохлятское': {'хохлятская',
#   'хохлятские',
#   'хохлятский',
#   'хохлятским',
#   'хохлятскими',
#   'хохлятских',
#   'хохлятского',
#   'хохлятское',
#   'хохлятской',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятскою',
#   'хохлятскую'},
#  'укропский': {'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'},
#  'укропская': {'укропскае',
#   'укропскаем',
#   'укропскай',
#   'укропскаю',
#   'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'},
#  'укропское': {'укропская',
#   'укропские',
#   'укропский',
#   'укропским',
#   'укропскими',
#   'укропских',
#   'укропского',
#   'укропское',
#   'укропской',
#   'укропском',
#   'укропскому',
#   'укропскою',
#   'укропскую'}}

# %%
df_ = pd.DataFrame([all_forms_dict])
df_.to_json('all_forms_dict.json',orient='records', lines=True)

# %%
word = 'ххлов'

if word in model.wv.key_to_index:
    word_vector = model.wv[word]
    print(f"The vector for the word '{word}':\n{word_vector}")
else:
    print(f"The word '{word}' is not in the vocabulary.")
# Out:
# The vector for the word 'ххлов':
# [-0.43288842  0.7436105  -0.09290253 -0.02120434  0.02870027 -0.13131145
#   0.11315405  0.03146933  0.19433673 -0.12791622  0.03809118 -0.29372498
#   0.27211308 -0.27973303 -0.412195   -0.03709674 -0.11171024  0.05461736
#  -0.27791902  0.16175213  0.07480086 -0.00944865 -0.01333196  0.3723256
#   0.60280013  0.0032816   0.0651744  -0.32838944 -0.23008314 -0.5041946
#  -0.23298502 -0.23291504  0.5789121  -0.05833485 -0.2310122   0.01809216
#  -0.26653925  0.6568714  -0.17577997 -0.15913822  0.02746626 -0.12497678
#  -0.05738966 -0.02048556  0.13583952 -0.22931214 -0.37275848 -0.17432179
#  -0.2166473   0.3330127   0.00532212  0.08767729 -0.0558027   0.22079192
#   0.13893016  0.23004353  0.10277361 -0.38730282  0.07255914  0.08250796
#  -0.06671572  0.39566067  0.3268311   0.00227097  0.00352522 -0.20208976
#  -0.29345524 -0.23287545 -0.31982905 -0.31867588 -0.2147223  -0.34511644
#   0.39490074 -0.37337115  0.01496766  0.2954205   0.21198319  0.21654636
#  -0.47028583 -0.3498678   0.63672644 -0.06712954  0.09876622 -0.17788792
#  -0.3969371   0.2963282  -0.01415201 -0.3118099   0.31856188 -0.26215634
#  -0.46228433 -0.31062353  0.19647591  0.26731873 -0.19189598  0.00399163
#   0.3673969   0.1836761   0.0849371  -0.13941827  0.5972032  -0.23299412
#  -0.18811543 -0.09988445  0.44717795 -0.03598525  0.19690694  0.19300911
#  -0.03444372 -0.45968312  0.40237468 -0.23197359  0.26166144  0.18830596
#  -0.11980731 -0.20897467  0.08156154 -0.21734     0.04048859  0.10544603
#  -0.26212853  0.39693224 -0.18507123  0.23155631  0.43725565  0.05473879
#   0.3503291  -0.5462728  -0.40480116  0.12949057 -0.21115422  0.01116453
#   0.16327795 -0.13752705  0.16580483  0.35749105 -0.11754303 -0.20202371
#  -0.15244989 -0.26552612  0.00668335 -0.15410429 -0.28423622  0.17517643
#  -0.02494987 -0.06880958 -0.13889094  0.26616895  0.3112839  -0.28940964]

# %%
final_forms_list = {}
for word in popular_label_list:
    final_forms_list[word]= list(all_forms_dict[word])+clean_misspellings_dict[word]

# %%
final_forms_list
# Out:
# {'укр': ['укр', 'укру', 'укри'],
#  'украинец': ['украинца',
#   'украинце',
#   'украинцам',
#   'украинцем',
#   'украинцах',
#   'украинцы',
#   'украинцами',
#   'украинцев',
#   'украинцу',
#   'украинец',
#   'украинци',
#   'украинц',
#   'украинеа',
#   'яукраинца',
#   'украинци',
#   'украинц',
#   'кукраинцам',
#   'усраинцам',
#   'украинцям',
#   'укранцем',
#   'украинцям',
#   'украинах',
#   'украинци',
#   'окраинцы',
#   'яукраинцы',
#   'украинц',
#   'украдинцы',
#   'украицы',
#   'усраинцы',
#   'укроинцы',
#   'украйнцы',
#   'краинцы',
#   'окраинцами',
#   'сукраинцами',
#   'украинами',
#   'оукраинцами',
#   'украинцева',
#   'иукраинцев',
#   'украинцеву',
#   'украинев',
#   'уукраинцев',
#   'укранцев',
#   'украинцевъ',
#   'украицев',
#   'усраинцев',
#   'окраинцев',
#   'украиснцев',
#   'уараинцев',
#   'украинцевс',
#   'украиньцев',
#   'украинци',
#   'украинц',
#   'украинеи',
#   'украинев',
#   'украинець',
#   'украинц',
#   'вукраинец',
#   'укранец',
#   'окраинец',
#   'украинес',
#   'иукраинец',
#   'украинеа',
#   'украиниц'],
#  'украинка': ['украинка',
#   'украинку',
#   'украинки',
#   'украинкой',
#   'украинками',
#   'украинках',
#   'украинке',
#   'украинок',
#   'украинкам',
#   'украинкою',
#   'укранка',
#   'краинка',
#   'украинци',
#   'украинеи',
#   'укранки',
#   'укринки',
#   'украино',
#   'укранок'],
#  'хохол': ['хохла',
#   'хохлу',
#   'хохлам',
#   'хохлом',
#   'хохлами',
#   'хохле',
#   'хохлах',
#   'хохлов',
#   'хохол',
#   'хохлы',
#   'хохл',
#   'хохли',
#   'хохлв',
#   'хохола',
#   'ххла',
#   'хохл',
#   'хохли',
#   'хохлух',
#   'хохлв',
#   'хихлам',
#   'лохлам',
#   'хохолам',
#   'хахлам',
#   'хихлами',
#   'хохлми',
#   'хохл',
#   'хохли',
#   'хохлв',
#   'хохлух',
#   'хихлах',
#   'холов',
#   'хохолов',
#   'ххлов',
#   'хахлов',
#   'лохлов',
#   'хохлв',
#   'хохолы',
#   'хохоль',
#   'хохл',
#   'ххол',
#   'хохола',
#   'хахол',
#   'хохоля',
#   'яхохол',
#   'хохолы',
#   'хихлы',
#   'ххлы',
#   'хохл',
#   'хахлы',
#   'хохли',
#   'лохлы',
#   'хохлв'],
#  'хохлушка': ['хохлушкою',
#   'хохлушкой',
#   'хохлушками',
#   'хохлушке',
#   'хохлушка',
#   'хохлушкам',
#   'хохлушек',
#   'хохлушках',
#   'хохлушку',
#   'хохлушки',
#   'хохлуша'],
#  'укроп': ['укропу',
#   'укропов',
#   'укропах',
#   'укропом',
#   'укроп',
#   'укропам',
#   'укропами',
#   'укропы',
#   'укропа',
#   'укропе',
#   'укров',
#   'укро',
#   'укром',
#   'укропка'],
#  'Украина': ['украиной',
#   'украину',
#   'украиною',
#   'украины',
#   'украине',
#   'украина',
#   'сукраиной',
#   'иукраиной',
#   'украинои',
#   'украино',
#   'букраиной',
#   'украной',
#   'укаиной',
#   'украиныой',
#   'оукраиной',
#   'украинуой',
#   'ураиной',
#   'усраиной',
#   'вукраину',
#   'украин',
#   'украини',
#   'украйну',
#   'иукраину',
#   'украинув',
#   'украино',
#   'укруину',
#   'укроину',
#   'усраину',
#   'укрину',
#   'украйину',
#   'ураину',
#   'букраину',
#   'украною',
#   'украинои',
#   'украино',
#   'украин',
#   'краины',
#   'иукраины',
#   'украны',
#   'украйны',
#   'украини',
#   'укрины',
#   'сукраины',
#   'ураины',
#   'букраины',
#   'уукраины',
#   'украиным',
#   'усраины',
#   'аукраины',
#   'украиныв',
#   'укруины',
#   'вукраины',
#   'украино',
#   'украиныи',
#   'укранины',
#   'укараины',
#   'вкраины',
#   'украиныр',
#   'кукраины',
#   'украиеы',
#   'укроины',
#   'укаины',
#   'вукраине',
#   'украин',
#   'украйне',
#   'украини',
#   'украинеи',
#   'ураине',
#   'укране',
#   'иукраине',
#   'укруине',
#   'кукраине',
#   'букраине',
#   'украино',
#   'укаине',
#   'усраине',
#   'укранине',
#   'укрине',
#   'украинеа',
#   'уукраине',
#   'укараине',
#   'украна',
#   'украин',
#   'украйна',
#   'иукраина',
#   'украини',
#   'аукраина',
#   'рукраина',
#   'укруина',
#   'украйина',
#   'украинах',
#   'украино',
#   'украинам',
#   'букраина',
#   'усраина',
#   'укрина',
#   'ураина',
#   'украинеа',
#   'тукраина',
#   'укараина',
#   'укранина',
#   'укаина'],
#  'украинский': ['украинской',
#   'украинскою',
#   'украинские',
#   'украинскую',
#   'украинское',
#   'украинская',
#   'украинских',
#   'украинским',
#   'украинскому',
#   'украинском',
#   'украинский',
#   'украинскими',
#   'украинского',
#   'украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'украинская': ['украинской',
#   'украинскою',
#   'украинские',
#   'украинскую',
#   'украинское',
#   'украинская',
#   'украинских',
#   'украинским',
#   'украинскому',
#   'украинском',
#   'украинский',
#   'украинскими',
#   'украинского',
#   'украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'украинское': ['украинской',
#   'украинскою',
#   'украинские',
#   'украинскую',
#   'украинское',
#   'украинская',
#   'украинских',
#   'украинским',
#   'украинскому',
#   'украинском',
#   'украинский',
#   'украинскими',
#   'украинского',
#   'украинскои',
#   'вукраинской',
#   'сукраинской',
#   'иукраинской',
#   'украинско',
#   'украиской',
#   'укранской',
#   'украиньской',
#   'усраинской',
#   'кукраинской',
#   'украинськой',
#   'краинской',
#   'укаинской',
#   'укринской',
#   'украиноской',
#   'украйнской',
#   'украинскои',
#   'украинско',
#   'украинською',
#   'украиньскою',
#   'украинскю',
#   'украински',
#   'украинскии',
#   'укранские',
#   'украиские',
#   'иукраинские',
#   'украинске',
#   'украинкие',
#   'украинскте',
#   'краинские',
#   'вукраинские',
#   'ураинские',
#   'окраинские',
#   'украйинские',
#   'украинския',
#   'украинснкие',
#   'укоаинские',
#   'украинскин',
#   'укранскую',
#   'вукраинскую',
#   'украинкую',
#   'украинскю',
#   'иукраинскую',
#   'украинскои',
#   'украинско',
#   'украинске',
#   'украинскте',
#   'украинсеое',
#   'иукраинское',
#   'иукраинская',
#   'украинкая',
#   'украинска',
#   'украинския',
#   'украинсккая',
#   'краинская',
#   'ураинская',
#   'украински',
#   'украинскии',
#   'иукраинских',
#   'украиских',
#   'укранских',
#   'украинких',
#   'вукраинских',
#   'украинських',
#   'укаинских',
#   'украинсих',
#   'украинцских',
#   'ураинских',
#   'украинския',
#   'украинскких',
#   'уукраинских',
#   'окраинских',
#   'укркинских',
#   'украинскин',
#   'краинских',
#   'украински',
#   'украинскии',
#   'сукраинским',
#   'украиским',
#   'кукраинским',
#   'иукраинским',
#   'укранским',
#   'украинскиму',
#   'украинския',
#   'окраинским',
#   'украинскин',
#   'кукраинскому',
#   'украинскиму',
#   'иукраинскому',
#   'украинскои',
#   'вукраинском',
#   'украинско',
#   'украмнском',
#   'окраинском',
#   'украиском',
#   'украинськом',
#   'украински',
#   'украинскии',
#   'украиский',
#   'укранский',
#   'вукраинский',
#   'украинський',
#   'краинский',
#   'иукраинский',
#   'укринский',
#   'украиинский',
#   'укаинский',
#   'украдинский',
#   'украинския',
#   'окраинский',
#   'ураинский',
#   'украиньский',
#   'аукраинский',
#   'украинскин',
#   'украйнский',
#   'украинскии',
#   'сукраинскими',
#   'иукраинскими',
#   'украинскиму',
#   'украинскми',
#   'украинкого',
#   'украинскаго',
#   'окраинского',
#   'краинского',
#   'украиньского',
#   'ураинского',
#   'украинскрго',
#   'укринского',
#   'украйнского',
#   'украиского',
#   'иукраинского'],
#  'хохлятский': ['хохлятских',
#   'хохлятского',
#   'хохлятским',
#   'хохлятскую',
#   'хохлятское',
#   'хохлятскою',
#   'хохлятский',
#   'хохлятская',
#   'хохлятскими',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятские',
#   'хохлятской',
#   'хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'хохлятская': ['хохлятских',
#   'хохлятского',
#   'хохлятским',
#   'хохлятскую',
#   'хохлятское',
#   'хохлятскою',
#   'хохлятский',
#   'хохлятская',
#   'хохлятскими',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятские',
#   'хохлятской',
#   'хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'хохлятское': ['хохлятских',
#   'хохлятского',
#   'хохлятским',
#   'хохлятскую',
#   'хохлятское',
#   'хохлятскою',
#   'хохлятский',
#   'хохлятская',
#   'хохлятскими',
#   'хохлятском',
#   'хохлятскому',
#   'хохлятские',
#   'хохлятской',
#   'хохлятски',
#   'хохлятски',
#   'хохлядскую',
#   'хохлятски',
#   'хохлядская',
#   'хохлядские',
#   'хохлятски'],
#  'укропский': ['укропскими',
#   'укропской',
#   'укропского',
#   'укропским',
#   'укропскою',
#   'укропские',
#   'укропское',
#   'укропском',
#   'укропский',
#   'укропских',
#   'укропская',
#   'укропскому',
#   'укропскую',
#   'укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровское',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровских',
#   'укропскии',
#   'укровская',
#   'укровскую'],
#  'укропская': ['укропскими',
#   'укропской',
#   'укропскай',
#   'укропского',
#   'укропским',
#   'укропскою',
#   'укропские',
#   'укропскае',
#   'укропскаю',
#   'укропском',
#   'укропский',
#   'укропское',
#   'укропская',
#   'укропскаем',
#   'укропскому',
#   'укропских',
#   'укропскую',
#   'укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровское',
#   'укровская',
#   'укровских',
#   'укропскии',
#   'укровскую'],
#  'укропское': ['укропскими',
#   'укропской',
#   'укропского',
#   'укропским',
#   'укропскою',
#   'укропские',
#   'укропское',
#   'укропском',
#   'укропский',
#   'укропских',
#   'укропская',
#   'укропскому',
#   'укропскую',
#   'укропскии',
#   'укровской',
#   'укровского',
#   'укровским',
#   'укропскии',
#   'укровские',
#   'укропскии',
#   'укровское',
#   'укровском',
#   'укровский',
#   'укропскии',
#   'укровских',
#   'укропскии',
#   'укровская',
#   'укровскую']}

# %%
# %%time

vectors_dict = {}
for word in popular_label_list:
    word_vec_list = [model.wv[form] for form in final_forms_list[word] if form in vocabulary]
    vectors_dict[word] = word_vec_list
# Out:
# CPU times: user 2.62 s, sys: 24.3 ms, total: 2.64 s
# Wall time: 2.64 s

# %%
# %%time

centroids_dict = {}
for word in popular_label_list:
    centroid_array=np.array(vectors_dict[word])
    centroid = np.mean(centroid_array, axis=0)
    centroids_dict[word] = centroid
# Out:
# CPU times: user 895 µs, sys: 850 µs, total: 1.75 ms
# Wall time: 1.27 ms

# %%
centroids_dict['украинск_'] = np.mean(np.vstack([centroids_dict['украинский'],centroids_dict['украинская'],centroids_dict['украинское']]), axis=0)

# %%
centroids_dict['хохлятск_'] = np.mean(np.vstack([centroids_dict['хохлятский'],centroids_dict['хохлятская'],centroids_dict['хохлятское']]), axis=0)

# %%
centroids_dict['укропск_'] = np.mean(np.vstack([centroids_dict['укропский'],centroids_dict['укропская'],centroids_dict['укропское']]), axis=0)

# %%
centroids_dict['украин_'] = np.mean(np.vstack([centroids_dict['украинец'],centroids_dict['украинка']]), axis=0)

# %%
centroids_dict['хох_'] = np.mean(np.vstack([centroids_dict['хохол'],centroids_dict['хохлушка']]), axis=0)

# %%
labels_to_rm = ['украинский', 'украинская', 'украинское', 'хохлятский', 'хохлятская', 'хохлятское', 'укропский', 'укропская', 'укропское']

for label in labels_to_rm:
    del centroids_dict[label]

# %%
centroids_dict.keys()
# Out:
# dict_keys(['укр', 'украинец', 'украинка', 'хохол', 'хохлушка', 'укроп', 'Украина', 'украинск_', 'хохлятск_', 'укропск_', 'украин_', 'хох_'])

# %%
centroids_dict
# Out:
# {'укр': array([-0.42878458, -0.14173278,  0.35514474,  0.30835035,  0.46497726,
#         -1.2164317 ,  0.58628994, -0.12765102,  0.3588579 , -0.4673873 ,
#          0.12715448, -0.16914482, -0.0426648 ,  0.6434408 ,  0.35352626,
#          0.2988735 ,  0.04927415,  0.3444352 ,  0.4261329 , -0.20419282,
#          0.04479333,  1.4654046 , -0.5292267 ,  0.28453726, -0.39278516,
#         -0.18567061,  0.17548023, -0.86843807,  1.0515684 ,  0.12538476,
#         -0.7291705 , -0.43656096, -0.81799984, -0.25885177, -0.43331102,
#          0.8611107 , -0.3890923 ,  0.33946648, -0.02101213,  0.4540206 ,
#          0.25284043,  0.10048433, -0.28265926, -0.15195934,  0.59896463,
#         -0.58201647, -0.68531245, -0.1788721 , -0.03205414,  0.2925841 ,
#         -0.05591347, -0.9945833 , -0.29373315, -0.5213817 , -1.3020766 ,
#          0.3862245 ,  0.10938714, -0.42029762,  1.1768816 , -0.60302633,
#          0.9622045 , -0.01683349, -0.7709419 ,  1.3404994 ,  0.07809808,
#         -0.6822796 , -0.44278026, -0.5837576 , -1.0209492 , -0.6281149 ,
#         -0.10836016, -0.3244871 ,  0.03839421,  0.10181393,  0.35103175,
#          0.07544004, -0.31043395, -0.25682068, -0.59062093,  0.26302156,
#          0.64407796, -1.025684  , -0.5000373 ,  0.37722632, -0.28479728,
#         -0.06789393, -0.5523451 , -1.2455348 ,  0.18506241, -0.37217534,
#         -0.2165687 , -0.4845183 ,  0.36050296, -0.22934417,  0.2156537 ,
#          0.05331177,  0.14321403, -0.62194616, -0.52573603,  0.12533648,
#          0.7988507 , -0.26069555, -0.48887432,  0.23203902,  0.30433995,
#         -0.4706466 , -0.11850496, -0.20178294,  0.04195289, -0.10216835,
#          1.1913952 , -0.12824675, -0.7614464 ,  0.28405845, -0.6421149 ,
#         -0.6248841 , -0.12260681, -0.28773293,  0.3433667 ,  0.45449576,
#         -0.79832274,  0.67743677,  0.0222099 , -0.39667428, -0.00187494,
#         -0.38236752,  0.4244982 , -0.5046975 , -0.5054567 ,  0.07382184,
#         -0.26456878,  0.21985315, -0.6635154 , -0.02462084,  0.44835976,
#          0.91804177, -0.3738141 ,  0.34673658, -0.07288222,  0.29875323,
#         -0.01699455,  0.6825456 , -0.24493319, -0.02546186,  0.09716469,
#          0.04004575,  0.2202368 , -0.2911693 ,  0.24870613, -0.15304428,
#         -0.08492473,  0.00236242,  0.03931647, -0.09491369, -0.06037028,
#          0.25684166,  0.17343141,  0.15019983,  0.05972674,  0.14674185,
#          0.16882876,  0.09362013,  0.16363122,  0.00361704,  0.1742181 ,
#         -0.18215716, -0.04434935,  0.05986591,  0.2926287 ,  0.344713  ,
#          0.10412876,  0.04562853, -0.11133922, -0.0973838 , -0.448764  ,
#          0.13784415,  0.18680662, -0.3333311 ,  0.03121702, -0.02788135,
#          0.13789645,  0.17086932, -0.09466326,  0.1042261 , -0.10839802,
#          0.120471  , -0.0961013 , -0.28542912, -0.28094104, -0.04998355,
#         -0.12878855, -0.01036518,  0.21710151, -0.22164428,  0.14703983,
#          0.16566417, -0.06660488,  0.19422808,  0.02230989,  0.09949744,
#          0.17282978,  0.07058365,  0.09067948,  0.24242073, -0.15775028,
#         -0.24308345, -0.00798657, -0.17495158,  0.11262254, -0.2771522 ,
#          0.2027946 , -0.19946219,  0.16200778, -0.02370586,  0.06275872,
#          0.29716572,  0.43906903, -0.07485512,  0.09872214,  0.08917703,
#          0.12484134, -0.01671482, -0.01066114, -0.01260233,  0.13321497,
#         -0.37037367,  0.1296446 ,  0.27689624, -0.15740955,  0.00533378,
#          0.166614  , -0.15851395, -0.2910224 , -0.10848138, -0.1793206 ,
#          0.09555128,  0.05418637, -0.1367194 ,  0.09552031, -0.00371505,
#          0.03286881,  0.23671918,  0.17068693, -0.04631543, -0.06801499,
#          0.12280823,  0.37118036, -0.09390299, -0.06922071,  0.03895182,
#         -0.1301274 ,  0.17203093, -0.07439888,  0.13992162, -0.06994238,
#          0.22738199, -0.2729941 ,  0.34022707, -0.14057635, -0.06935479,
#          0.19678777, -0.13466157, -0.0214786 ,  0.15604216,  0.40280178,
#          0.09010072, -0.02746816, -0.04940027,  0.19526006, -0.0771669 ],
#        dtype=float32)}

# %%
import numpy as np

def save_dictionary_to_file(dictionary, file_name):
    np.savez(file_name, **dictionary)

# %%
save_dictionary_to_file(centroids_dict, 'centroids_dict.npz')

# %%
# import numpy as np
#
# def load_dictionary_from_file(file_name):
#     with np.load(file_name) as data:
#         return {key: data[key] for key in data}

# %%
# loaded_dict = load_dictionary_from_file('centroids_dict.npz')

# %% [markdown]
# ### Training on the 3-month timesteps

# %%
import pandas as pd
import ast
import numpy as np
from gensim.models import Word2Vec
from datetime import timedelta

# %%
# %%time
df_lemmas_all_time = pd.read_csv('/Users/katerynaburovova/PycharmProjects/dehumanization/data/all_lemmas_w_dates.csv', index_col=[0])
# Out:
# CPU times: user 2min 52s, sys: 1min 16s, total: 4min 8s
# Wall time: 7min 57s

# %%
# We need to parse lists correctly but in the way that's affordable in terms of memory
chunk_size = 5000
def process_chunk(chunk):
    chunk['message_lemmas_list'] = chunk['message_lemmas_list'].apply(ast.literal_eval)
    return chunk
chunks = []

# %%
# %%time

for start in range(0, len(df_lemmas_all_time), chunk_size):
    end = start + chunk_size
    chunk = df_lemmas_all_time.iloc[start:end].copy()
    processed_chunk = process_chunk(chunk)
    chunks.append(processed_chunk)

df_lemmas_all_time = pd.concat(chunks, axis=0)
# Out:
# CPU times: user 6min 58s, sys: 4min 34s, total: 11min 32s
# Wall time: 29min 26s

# %%
# %%time
df_lemmas_all_time['date_formatted'] = pd.to_datetime(df_lemmas_all_time['date_formatted'])
# Out:
# CPU times: user 2.43 s, sys: 20.8 s, total: 23.2 s
# Wall time: 1min 41s

# %%
def divide_into_timesteps(df, timedelta_months=3):
    min_date = df['date_formatted'].min()
    max_date = df['date_formatted'].max()
    time_step_limit = min_date + pd.DateOffset(months=timedelta_months)

    time_slices = []
    while time_step_limit <= max_date:
        time_slice = df[(df['date_formatted'] >= min_date) & (df['date_formatted'] < time_step_limit)]
        time_slices.append(time_slice)
        min_date = time_step_limit
        time_step_limit = time_step_limit + pd.DateOffset(months=timedelta_months)

    if min_date < max_date:
        time_slice = df[df['date_formatted'] >= min_date]
        time_slices.append(time_slice)

    return time_slices

# %%
# %%time
time_slices = divide_into_timesteps(df_lemmas_all_time)
# Out:
# CPU times: user 3.72 s, sys: 54.4 s, total: 58.1 s
# Wall time: 4min 32s

# %%
len(time_slices)
# Out:
# 30

# %%
time_slices[0]
# Out:
#             id            date_formatted  \
# 235734   150.0 2015-12-22 06:00:32+00:00
# 235735   149.0 2015-12-21 06:03:00+00:00
# 235736   148.0 2015-12-20 08:05:28+00:00
# 235737   147.0 2015-12-19 08:13:32+00:00
# 235738   146.0 2015-12-18 06:08:16+00:00
# ...        ...                       ...
# 5638168   10.0 2015-09-28 12:44:55+00:00
# 5638169    9.0 2015-09-28 09:14:53+00:00
# 5638170    8.0 2015-09-24 13:48:28+00:00
# 5638171    7.0 2015-09-24 11:40:51+00:00
# 5638172    6.0 2015-09-24 11:05:54+00:00
#
#                                                    message  \
# 235734   Доброе утро!  Самое важное к этому часу  Ракет...
# 235735   Доброе утро!  Главные новости к этому часу:   ...
# 235736   Хорошего вам воскресенья! Вот главные новости ...
# 235737   Доброе утро! Вот главные новости к этому часу:...
# 235738   Доброе утро! Вот главные новости:    Reuters у...
# ...                                                    ...
# 5638168  «Форд» будет производиться в Калининграде http...
# 5638169  В президентский авиапарк купят еще два командн...
# 5638170  «В 2015 году продажи российского кино за рубеж...
# 5638171  Более 80% россиян против повышения пенсионного...
# 5638172  Глава Коми просится из СИЗО в московскую кварт...
#
#                                              message_final channel_name  \
# 235734   доброе утро  самое важное к этому часу  ракета...       tvrain
# 235735   доброе утро  главные новости к этому часу  в к...       tvrain
# 235736   хорошего вам воскресенья вот главные новости к...       tvrain
# 235737   доброе утро вот главные новости к этому часу  ...       tvrain
# 235738   доброе утро вот главные новости     узнало о с...       tvrain
# ...                                                    ...          ...
# 5638168             форд будет производиться вкалининграде     izvestia
# 5638169  в президентский авиапарк купят еще два командн...     izvestia
# 5638170  в  году продажи российского кино за рубеж сост...     izvestia
# 5638171  более  россиян против повышения пенсионного во...     izvestia
# 5638172  глава коми просится из сизо в московскую кварт...     izvestia
#
#                                        message_lemmas_list
# 235734   [добрый, утро,  , самое, важный, к, этот, час,...
# 235735   [добрый, утро,  , главный, новость, к, этот, ч...
# 235736   [хороший, вам, воскресение, вот, главный, ново...
# 235737   [добрый, утро, вот, главный, новость, к, этот,...
# 235738   [добрый, утро, вот, главный, новость,     , уз...
# ...                                                    ...
# 5638168        [форд, будет, производиться, вкалининграде]
# 5638169  [в, президентский, авиапарк, купить, еще, два,...
# 5638170  [в,  , год, продажа, российский, кино, за, руб...
# 5638171  [более,  , россиянин, против, повышение, пенси...
# 5638172  [глава, коми, просится, из, сизо, в, московски...
#
# [4311 rows x 6 columns]

# %%
model_path = "/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/final_models/full_dataset_word2vec_correct.model"
gensim_model = Word2Vec.load(model_path)

# %%
# for i, df in enumerate(time_slices):
#     df.to_csv(f'/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/time_step_dataframes/dataframe_{i}.csv', index=False)

# %%
# import copy
#
# def train_word2vec_models(base_model, time_slices):
#     epochs = 20
#     timestep_models = []
#
#     for time_slice in time_slices:
#         iter_model = copy.deepcopy(base_model)
#         documents = time_slice['message_lemmas_list'].to_list()
#
#         iter_model.build_vocab(documents, update=True)
#         iter_model.train(documents,
#                          total_examples=iter_model.corpus_count,
#                          epochs=epochs)
#         timestep_models.append(iter_model)
#
#     return timestep_models

# %%
# import os
#
# slices_directory = '/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/time_step_dataframes'
#
# for i, time_slice in enumerate(time_slices):
#     if i<27:
#         continue
#     else:
#         start_date = time_slice['date_formatted'].min().strftime("%Y-%m-%d")
#         end_date = time_slice['date_formatted'].max().strftime("%Y-%m-%d")
#         slice_name = f"df_time_slice_{i+1}_{start_date}_to_{end_date}.csv"
#         slice_path = os.path.join(slices_directory, slice_name)
#         time_slice.to_csv(slice_path)
#         print(f"Done with {slice_name}")
# Out:
# Done with df_time_slice_28_2022-06-22_to_2022-09-22.csv
# Done with df_time_slice_29_2022-09-22_to_2022-12-22.csv
# Done with df_time_slice_30_2022-12-22_to_2022-12-26.csv

# %%
import os
import pandas as pd

slices_directory = '/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/time_step_dataframes'
time_slices = []
file_names = os.listdir(slices_directory)

file_names = sorted(file_names, key=lambda name: int(name.split('_')[3]) if name.endswith('.csv') else float('inf'))

# %%
print(file_names)
# Out:
# ['df_time_slice_1_2015-09-22_to_2015-12-22.csv', 'df_time_slice_2_2015-12-23_to_2016-03-22.csv', 'df_time_slice_3_2016-03-23_to_2016-06-22.csv', 'df_time_slice_4_2016-06-22_to_2016-09-22.csv', 'df_time_slice_5_2016-09-22_to_2016-12-22.csv', 'df_time_slice_6_2016-12-22_to_2017-03-22.csv', 'df_time_slice_7_2017-03-22_to_2017-06-22.csv', 'df_time_slice_8_2017-06-22_to_2017-09-22.csv', 'df_time_slice_9_2017-09-22_to_2017-12-22.csv', 'df_time_slice_10_2017-12-22_to_2018-03-22.csv', 'df_time_slice_11_2018-03-22_to_2018-06-22.csv', 'df_time_slice_12_2018-06-22_to_2018-09-22.csv', 'df_time_slice_13_2018-09-22_to_2018-12-22.csv', 'df_time_slice_14_2018-12-22_to_2019-03-22.csv', 'df_time_slice_15_2019-03-22_to_2019-06-22.csv', 'df_time_slice_16_2019-06-22_to_2019-09-22.csv', 'df_time_slice_17_2019-09-22_to_2019-12-22.csv', 'df_time_slice_18_2019-12-22_to_2020-03-22.csv', 'df_time_slice_19_2020-03-22_to_2020-06-22.csv', 'df_time_slice_20_2020-06-22_to_2020-09-22.csv', 'df_time_slice_21_2020-09-22_to_2020-12-22.csv', 'df_time_slice_22_2020-12-22_to_2021-03-22.csv', 'df_time_slice_23_2021-03-22_to_2021-06-22.csv', 'df_time_slice_24_2021-06-22_to_2021-09-22.csv', 'df_time_slice_25_2021-09-22_to_2021-12-22.csv', 'df_time_slice_26_2021-12-22_to_2022-03-22.csv', 'df_time_slice_27_2022-03-22_to_2022-06-22.csv', 'df_time_slice_28_2022-06-22_to_2022-09-22.csv', 'df_time_slice_29_2022-09-22_to_2022-12-22.csv', 'df_time_slice_30_2022-12-22_to_2022-12-26.csv']

# %%
# %%time
for file_name in file_names:
    if file_name.endswith('.csv'):
        file_path = os.path.join(slices_directory, file_name)
        df = pd.read_csv(file_path, index_col=0)
        df['date_formatted'] = pd.to_datetime(df['date_formatted'])
        # print(type(df.date_formatted.iloc[0]))
        time_slices.append(df)

print("Loaded all time_slices dataframes into the list.")
# Out:
# Loaded all time_slices dataframes into the list.
# CPU times: user 2min 46s, sys: 27.7 s, total: 3min 14s
# Wall time: 3min 40s

# %%
# type(time_slices[0].date_formatted.iloc[0])

# %%
import copy
def train_word2vec_models(base_model, time_slices, models_directory):
    epochs = 20
    timestep_models = []

    for i, time_slice in enumerate(time_slices):
        if i<26:
            continue
        else:
            iter_model = copy.deepcopy(base_model)
            documents = time_slice['message_lemmas_list'].to_list()

            iter_model.build_vocab(documents, update=True)
            iter_model.train(documents,
                             total_examples=iter_model.corpus_count,
                             epochs=epochs)

            start_date = time_slice['date_formatted'].min().strftime("%Y-%m-%d")
            end_date = time_slice['date_formatted'].max().strftime("%Y-%m-%d")
            model_name = f"word2vec_time_slice_{i+1}_{start_date}_to_{end_date}.model"
            model_path = os.path.join(models_directory, model_name)
            iter_model.save(model_path)

            timestep_models.append(iter_model)
            print(f"Done with {model_name}")

    return timestep_models

# %%
# import copy
# def train_word2vec_models(base_model, time_slices, models_directory):
#     epochs = 20
#     timestep_models = []
#
#     for i, time_slice in enumerate(time_slices):
#         iter_model = copy.deepcopy(base_model)
#         documents = time_slice['message_lemmas_list'].to_list()
#
#         iter_model.build_vocab(documents, update=True)
#         iter_model.train(documents,
#                          total_examples=iter_model.corpus_count,
#                          epochs=epochs)
#
#         start_date = time_slice['date_formatted'].min().strftime("%Y-%m-%d")
#         end_date = time_slice['date_formatted'].max().strftime("%Y-%m-%d")
#         model_name = f"word2vec_time_slice_{i+1}_{start_date}_to_{end_date}.model"
#         model_path = os.path.join(models_directory, model_name)
#         iter_model.save(model_path)
#
#         timestep_models.append(iter_model)
#         print(f"Done with {model_name}")
#
#     return timestep_models

# %%
import os
from gensim.models import Word2Vec

# %%
models_directory = '/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/models_in_time_more_ep'
timestep_models = train_word2vec_models(gensim_model, time_slices, models_directory)
# Out:
# Done with word2vec_time_slice_27_2022-03-22_to_2022-06-22.model
# Done with word2vec_time_slice_28_2022-06-22_to_2022-09-22.model
# Done with word2vec_time_slice_29_2022-09-22_to_2022-12-22.model
# Done with word2vec_time_slice_30_2022-12-22_to_2022-12-26.model

# %% [markdown]
# ## Reading models and calculating the nearest N

# %%
import os
from gensim.models import Word2Vec
from typing import List

# %%
# %%time
#
# models_directory = "/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/models_in_time"
# model_filenames = [f for f in os.listdir(models_directory) if f.endswith(".model")]
#
# models = []
# for filename in model_filenames:
#     model_path = os.path.join(models_directory, filename)
#     models.append(Word2Vec.load(model_path))

# %%
# def find_closest_words(models: List[Word2Vec], given_vector, topn: int = 100):
#     all_closest_words = []
#     for model in models:
#         closest_words = model.wv.similar_by_vector(given_vector, topn=topn)
#         all_closest_words.extend(closest_words)
#     return all_closest_words

# %%
def find_closest_words_for_single_model(model_path: str, given_vector, topn: int = 10):
    try:
        model = Word2Vec.load(model_path)
        closest_words = model.wv.similar_by_vector(given_vector, topn=topn)
        del model
        return closest_words
    except Exception as e:
        print(f"Error processing model {model_path}: {e}")
        return []

# %%
models_directory = "/Users/katerynaburovova/PycharmProjects/dehumanization/w2v_models/models_in_time"
model_filenames = [f for f in os.listdir(models_directory) if f.endswith(".model")]

# %%
centroids_dict['укр']
# Out:
# array([-0.42878458, -0.14173278,  0.35514474,  0.30835035,  0.46497726,
#        -1.2164317 ,  0.58628994, -0.12765102,  0.3588579 , -0.4673873 ,
#         0.12715448, -0.16914482, -0.0426648 ,  0.6434408 ,  0.35352626,
#         0.2988735 ,  0.04927415,  0.3444352 ,  0.4261329 , -0.20419282,
#         0.04479333,  1.4654046 , -0.5292267 ,  0.28453726, -0.39278516,
#        -0.18567061,  0.17548023, -0.86843807,  1.0515684 ,  0.12538476,
#        -0.7291705 , -0.43656096, -0.81799984, -0.25885177, -0.43331102,
#         0.8611107 , -0.3890923 ,  0.33946648, -0.02101213,  0.4540206 ,
#         0.25284043,  0.10048433, -0.28265926, -0.15195934,  0.59896463,
#        -0.58201647, -0.68531245, -0.1788721 , -0.03205414,  0.2925841 ,
#        -0.05591347, -0.9945833 , -0.29373315, -0.5213817 , -1.3020766 ,
#         0.3862245 ,  0.10938714, -0.42029762,  1.1768816 , -0.60302633,
#         0.9622045 , -0.01683349, -0.7709419 ,  1.3404994 ,  0.07809808,
#        -0.6822796 , -0.44278026, -0.5837576 , -1.0209492 , -0.6281149 ,
#        -0.10836016, -0.3244871 ,  0.03839421,  0.10181393,  0.35103175,
#         0.07544004, -0.31043395, -0.25682068, -0.59062093,  0.26302156,
#         0.64407796, -1.025684  , -0.5000373 ,  0.37722632, -0.28479728,
#        -0.06789393, -0.5523451 , -1.2455348 ,  0.18506241, -0.37217534,
#        -0.2165687 , -0.4845183 ,  0.36050296, -0.22934417,  0.2156537 ,
#         0.05331177,  0.14321403, -0.62194616, -0.52573603,  0.12533648,
#         0.7988507 , -0.26069555, -0.48887432,  0.23203902,  0.30433995,
#        -0.4706466 , -0.11850496, -0.20178294,  0.04195289, -0.10216835,
#         1.1913952 , -0.12824675, -0.7614464 ,  0.28405845, -0.6421149 ,
#        -0.6248841 , -0.12260681, -0.28773293,  0.3433667 ,  0.45449576,
#        -0.79832274,  0.67743677,  0.0222099 , -0.39667428, -0.00187494,
#        -0.38236752,  0.4244982 , -0.5046975 , -0.5054567 ,  0.07382184,
#        -0.26456878,  0.21985315, -0.6635154 , -0.02462084,  0.44835976,
#         0.91804177, -0.3738141 ,  0.34673658, -0.07288222,  0.29875323,
#         0.04982388, -0.67343074, -0.530287  ,  0.4103795 ,  0.6199675 ,
#         0.8070428 ,  0.28452083,  0.14078917, -0.19571054,  0.12694328],
#       dtype=float32)

# %%
def get_all_nearest_wordvecs(key, model_filenames=model_filenames, topn=10):
    all_closest_words = []

    for filename in model_filenames:
        model_path = os.path.join(models_directory, filename)
        closest_words = find_closest_words_for_single_model(model_path, key, topn=topn)
        all_closest_words.extend(closest_words)
        # print(f'Done with model {filename}')

    unique_closest_words = list(dict(all_closest_words).items())

    return unique_closest_words

# %%
# %%time

nearest_ukr = get_all_nearest_wordvecs(centroids_dict['укр'])
# Out:
# CPU times: user 1min 52s, sys: 36.3 s, total: 2min 29s
# Wall time: 1min 57s

# %%
# closest_words = find_closest_words_for_single_model(model_path, centroids_dict['укр'], topn=100)

# %%
nearest_ukr
# Out:
# [('укр', 0.977008044719696),
#  ('укро', 0.6340225338935852),
#  ('насмикав', 0.5467818975448608),
#  ('зрадная', 0.5411729216575623),
#  ('кляти', 0.524753987789154),
#  ('мюмзики', 0.5390231013298035),
#  ('укроканалы', 0.526896595954895),
#  ('цханоская', 0.5222957730293274),
#  ('венерична', 0.5210613012313843),
#  ('ефрв', 0.5089078545570374),
#  ('мыкола', 0.5238763093948364),
#  ('шароварный', 0.512841522693634),
#  ('укрорейха', 0.5100848078727722),
#  ('хохлы', 0.5254834890365601),
#  ('хохол', 0.5190120339393616),
#  ('щирый', 0.5069569945335388),
#  ('укропской', 0.518076479434967)]

# %%
len(nearest_ukr)
# Out:
# 17

# %%
# %%time
nearest_vals_dict = {}
for key in centroids_dict.keys():
    nearest_vals_dict[key] = get_all_nearest_wordvecs(centroids_dict[key])
# Out:
# CPU times: user 23min 49s, sys: 5min 53s, total: 29min 42s
# Wall time: 22min 21s

# %%
nearest_vals_dict
# Out:
# {'укр': [('укр', 0.977008044719696),
#   ('укро', 0.6340225338935852),
#   ('насмикав', 0.5467818975448608),
#   ('зрадная', 0.5411729216575623),
#   ('кляти', 0.524753987789154),
#   ('мюмзики', 0.5390231013298035),
#   ('укроканалы', 0.526896595954895),
#   ('цханоская', 0.5222957730293274),
#   ('венерична', 0.5210613012313843),
#   ('ефрв', 0.5089078545570374),
#   ('мыкола', 0.5238763093948364),
#   ('шароварный', 0.512841522693634),
#   ('укрорейха', 0.5100848078727722),
#   ('хохлы', 0.5254834890365601),
#   ('хохол', 0.5190120339393616),
#   ('щирый', 0.5069569945335388),
#   ('укропской', 0.518076479434967)],
#  'украинец': [('украинец', 0.7451037764549255),
#   ('украинци', 0.6607651114463806),
#   ('киевлянин', 0.6365122199058533),
#   ('одессит', 0.6031530499458313),
#   ('харьковчанин', 0.563445508480072),
#   ('львовянин', 0.5659374594688416),
#   ('москаль', 0.558702826499939),
#   ('белорус', 0.5650672912597656),
#   ('украинка', 0.5572485327720642),
#   ('волынянин', 0.5463880896568298),
#   ('русских', 0.5700317025184631),
#   ('поляк', 0.557224690914154),
#   ('хохол', 0.551811158657074),
#   ('русские', 0.5469532012939453),
#   ('галичанин', 0.5279514789581299),
#   ('западенец', 0.5290453433990479),
#   ('выговский', 0.5380120277404785),
#   ('портников', 0.529964029788971),
#   ('березовец', 0.5267285704612732),
#   ('садура', 0.5204106569290161),
#   ('малогосударствообразующие', 0.5395024418830872)],
#  'украинка': [('украинка', 0.9199673533439636),
#   ('харьковчанка', 0.6617604494094849),
#   ('полячка', 0.6355076432228088),
#   ('беженка', 0.6371013522148132),
#   ('киевлянка', 0.6415326595306396),
#   ('кунис', 0.630091667175293),
#   ('одесситка', 0.6224566102027893),
#   ('девушка', 0.6362607479095459),
#   ('немка', 0.5984247922897339),
#   ('белоруска', 0.5953155159950256),
#   ('фотомодель', 0.5996046662330627),
#   ('бандеровка', 0.5870457887649536),
#   ('британка', 0.5926914811134338),
#   ('женщина', 0.6092566847801208),
#   ('итальянка', 0.5991948246955872),
#   ('россиянка', 0.5995811223983765)],
#  'хохол': [('хохол', 0.791834831237793),
#   ('хохлы', 0.7910692095756531),
#   ('укроп', 0.711285412311554),
#   ('хохлов', 0.6768572926521301),
#   ('укропитеки', 0.6565565466880798),
#   ('хохла', 0.6503580808639526),
#   ('чубатый', 0.6536758542060852),
#   ('укров', 0.6426442861557007),
#   ('кацап', 0.6432580351829529),
#   ('укры', 0.645832359790802),
#   ('укропы', 0.6437776684761047),
#   ('свинособаки', 0.621316134929657),
#   ('рагулье', 0.6083755493164062),
#   ('бандерлоги', 0.6077458262443542)],
#  'хохлушка': [('хохлушка', 0.9628682136535645),
#   ('шмара', 0.6192910075187683),
#   ('бабища', 0.6126108169555664),
#   ('нацистка', 0.608944833278656),
#   ('шалава', 0.6071863770484924),
#   ('бандеровка', 0.5831304788589478),
#   ('жинка', 0.5675132870674133),
#   ('бабёнка', 0.5636026263237),
#   ('девка', 0.5635061264038086),
#   ('дамочка', 0.5696848630905151),
#   ('карлица', 0.5649908185005188),
#   ('мерзавка', 0.5591220259666443),
#   ('украинка', 0.5715823769569397),
#   ('деваха', 0.5652415752410889),
#   ('парубок', 0.5589596629142761),
#   ('рогули', 0.5571290254592896)],
#  'укроп': [('укроп', 0.8941603302955627),
#   ('укров', 0.7887672185897827),
#   ('укропы', 0.7400252819061279),
#   ('укропов', 0.7537237405776978),
#   ('всушников', 0.7206322550773621),
#   ('укры', 0.7231354713439941),
#   ('укронацистов', 0.7145315408706665),
#   ('всушники', 0.7081602811813354),
#   ('хохол', 0.6965129375457764),
#   ('свинорылых', 0.6784160137176514),
#   ('всук', 0.6508971452713013),
#   ('укропитеков', 0.6464940309524536),
#   ('укропские', 0.6461158394813538),
#   ('свинособак', 0.6389224529266357),
#   ('всуки', 0.6460868716239929)],
#  'Украина': [('украина', 0.6692848801612854),
#   ('украин', 0.6248115301132202),
#   ('украины', 0.5897771120071411),
#   ('наукраине', 0.5847060680389404),
#   ('украине', 0.5739821195602417),
#   ('иукраины', 0.5665566325187683),
#   ('усср', 0.5613463521003723),
#   ('вукраине', 0.5558258891105652),
#   ('украны', 0.5414850115776062),
#   ('вдонбассе', 0.5318649411201477),
#   ('наукраину', 0.5282232165336609),
#   ('донбасс', 0.5411754846572876),
#   ('впольше', 0.5320767164230347),
#   ('вкиеве', 0.5160347819328308)],
#  'украинск_': [('украинские', 0.7997097969055176),
#   ('украинским', 0.8250154256820679),
#   ('украинского', 0.7708936929702759),
#   ('украинскими', 0.7364920377731323),
#   ('украинских', 0.786467969417572),
#   ('украинской', 0.757716715335846),
#   ('украинский', 0.7883399128913879),
#   ('украинскую', 0.7072377800941467),
#   ('украинское', 0.7150611281394958),
#   ('украинская', 0.689694881439209),
#   ('украинском', 0.6765651702880859),
#   ('украинскому', 0.5655392408370972),
#   ('укр', 0.565543532371521)],
#  'хохлятск_': [('хохлятские', 0.7342333793640137),
#   ('хохлятских', 0.7035917043685913),
#   ('свинорылых', 0.6740872859954834),
#   ('хохлятский', 0.6696254014968872),
#   ('хохлятской', 0.6445931792259216),
#   ('свинопас', 0.6462036967277527),
#   ('хохлятского', 0.6365864872932434),
#   ('укропитеки', 0.6342765092849731),
#   ('укро', 0.6334356069564819),
#   ('укропитеков', 0.6276661157608032),
#   ('долбаебы', 0.6554622054100037),
#   ('чубатый', 0.6316072344779968),
#   ('пдрвля', 0.6169582605361938),
#   ('всушный', 0.6263797283172607),
#   ('укропские', 0.6214194297790527)],
#  'укропск_': [('укропские', 0.7384203672409058),
#   ('укропских', 0.7136443257331848),
#   ('свинорылых', 0.7014429569244385),
#   ('укропской', 0.6972910761833191),
#   ('укровермахта', 0.6729861497879028),
#   ('всук', 0.6714401841163635),
#   ('укро', 0.6642491817474365),
#   ('укропская', 0.6562466025352478),
#   ('всн', 0.6397643089294434),
#   ('укроп', 0.6414011716842651),
#   ('укропский', 0.6477977633476257),
#   ('укровский', 0.639269232749939),
#   ('всушный', 0.6433415412902832),
#   ('укровские', 0.6214118003845215),
#   ('хохлятского', 0.6333475708961487),
#   ('всушные', 0.6317546963691711)],
#  'украин_': [('украинка', 0.8975982069969177),
#   ('харьковчанка', 0.6602419018745422),
#   ('одесситка', 0.6352112293243408),
#   ('киевлянка', 0.6329371929168701),
#   ('кунис', 0.6278789043426514),
#   ('полячка', 0.6199662089347839),
#   ('украинец', 0.6384974718093872),
#   ('беженка', 0.6051002144813538),
#   ('бацман', 0.5890083909034729),
#   ('белоруска', 0.5823470950126648),
#   ('немка', 0.5817163586616516),
#   ('ницой', 0.5850912928581238),
#   ('лыжичко', 0.5824093222618103),
#   ('девушка', 0.5913671255111694)],
#  'хох_': [('хохлушка', 0.8745825886726379),
#   ('хохол', 0.6529718637466431),
#   ('чубатый', 0.6410849690437317),
#   ('хлопец', 0.6414433121681213),
#   ('кацап', 0.6309615969657898),
#   ('хохлы', 0.6350769996643066),
#   ('укропитеки', 0.6247252225875854),
#   ('свинособак', 0.6223528981208801),
#   ('пздц', 0.6194047927856445),
#   ('рогули', 0.6212472915649414),
#   ('парубок', 0.5998139381408691),
#   ('свинособака', 0.6079042553901672),
#   ('хлопци', 0.6061328053474426),
#   ('хлопчик', 0.5963305234909058),
#   ('свинособаки', 0.585556149482727),
#   ('жинка', 0.5968509316444397)]}

# %%
expanded_target_label_list = [item[0] for key in nearest_vals_dict for item in nearest_vals_dict[key]]

# %%
len(expanded_target_label_list)
# Out:
# 187

# %%
expanded_target_label_list = list(set(expanded_target_label_list))

# %%
len(expanded_target_label_list)
# Out:
# 139

# %%
import json

file_name = "/Users/katerynaburovova/PycharmProjects/dehumanization/annotation/new_batch/expanded_target_labels.json"

with open(file_name, "w") as file:
    json.dump(expanded_target_label_list, file)

# %%
with open(file_name, "r") as file:
    loaded_unique_vals = json.load(file)

print(loaded_unique_vals)
# Out:
# ['женщина', 'хохлятских', 'беженка', 'укровские', 'укропы', 'белорус', 'киевлянка', 'украинскую', 'малогосударствообразующие', 'харьковчанин', 'мерзавка', 'свинорылых', 'укронацистов', 'хохлятской', 'портников', 'украинской', 'кунис', 'пдрвля', 'украинское', 'свинособаки', 'бандерлоги', 'укропитеков', 'укрорейха', 'бабища', 'хлопчик', 'украинская', 'киевлянин', 'усср', 'чубатый', 'западенец', 'шмара', 'хлопци', 'хохла', 'укропской', 'жинка', 'вукраине', 'девка', 'карлица', 'щирый', 'укроп', 'наукраине', 'укры', 'хохлятский', 'мюмзики', 'укропов', 'наукраину', 'бацман', 'садура', 'белоруска', 'донбасс', 'украинскому', 'всук', 'зрадная', 'украинец', 'украина', 'пздц', 'бабёнка', 'свинособак', 'деваха', 'украинци', 'укр', 'насмикав', 'украинский', 'полячка', 'бандеровка', 'харьковчанка', 'долбаебы', 'немка', 'русских', 'украин', 'укропская', 'девушка', 'итальянка', 'поляк', 'украны', 'ницой', 'впольше', 'украинские', 'украинских', 'цханоская', 'укроканалы', 'лыжичко', 'всушный', 'хохлятские', 'вкиеве', 'шароварный', 'всуки', 'одессит', 'дамочка', 'укро', 'фотомодель', 'украинскими', 'выговский', 'украины', 'всушники', 'укропских', 'шалава', 'иукраины', 'москаль', 'хохлы', 'всушные', 'украине', 'украинском', 'хлопец', 'хохол', 'кляти', 'свинособака', 'мыкола', 'британка', 'укровский', 'вдонбассе', 'хохлов', 'венерична', 'всушников', 'всн', 'хохлушка', 'украинским', 'украинского', 'рагулье', 'ефрв', 'украинка', 'русские', 'березовец', 'свинопас', 'львовянин', 'одесситка', 'укропский', 'кацап', 'рогули', 'волынянин', 'укропитеки', 'парубок', 'россиянка', 'хохлятского', 'укровермахта', 'укров', 'нацистка', 'укропские', 'галичанин']

# %%
# Do we need inflections?
